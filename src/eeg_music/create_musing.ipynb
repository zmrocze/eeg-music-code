# %%
from pathlib import Path

import matplotlib.pyplot as plt
import mne
import numpy as np
from numpy.typing import NDArray

from eeg_music.data import EEGMusicDataset
from eeg_music.ica_analysis import (
    apply_ica,
    clean_ica_artifacts,
    ica_band_power_trial,
    ica_band_power_trial_1020,
    windowed_band_power,
    _prepare_raw_1020,
)

# %%
# ds = EEGMusicDataset.load_ondisk(Path("./datasets/bcmi_preprocessed/bcmi_training_export"))
from eeg_music.bcmi import BCMIMusingLoader, create_bcmi_loader
from eeg_music.data import copy_from_dataloader_into_dir


musing_loader = BCMIMusingLoader("./datasets/musin_g_data", dataset_name="musin-g")

musing_loader.load_all_subjects()
copy_from_dataloader_into_dir(musing_loader, Path("./datasets/musing_g_export_3"))
# Out:
# Loading subject 001 (musin-g):
#   ✓ Song 01 (run 1): 136.0s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-01/eeg/sub-001_ses-01_task-MusicListening_run-1_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-02/eeg/sub-001_ses-02_task-MusicListening_run-2_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-03/eeg/sub-001_ses-03_task-MusicListening_run-3_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 02 (run 2): 124.9s, 128 events
#   ✓ Song 03 (run 3): 142.8s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-04/eeg/sub-001_ses-04_task-MusicListening_run-4_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 04 (run 4): 121.5s, 128 events
#   ✓ Song 05 (run 5): 134.6s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-05/eeg/sub-001_ses-05_task-MusicListening_run-5_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-06/eeg/sub-001_ses-06_task-MusicListening_run-6_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 06 (run 6): 110.1s, 128 events
#   ✓ Song 07 (run 7): 126.5s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-07/eeg/sub-001_ses-07_task-MusicListening_run-7_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 107 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-08/eeg/sub-001_ses-08_task-MusicListening_run-8_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 08 (run 8): 131.8s, 128 events
#   ✓ Song 09 (run 9): 136.5s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-09/eeg/sub-001_ses-09_task-MusicListening_run-9_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-10/eeg/sub-001_ses-10_task-MusicListening_run-10_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 10 (run 10): 139.5s, 128 events
#   ✓ Song 11 (run 11): 123.1s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-11/eeg/sub-001_ses-11_task-MusicListening_run-11_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 109 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-001/ses-12/eeg/sub-001_ses-12_task-MusicListening_run-12_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 12 (run 12): 127.8s, 128 events
# Loading subject 002 (musin-g):
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-01/eeg/sub-002_ses-01_task-MusicListening_run-1_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-02/eeg/sub-002_ses-02_task-MusicListening_run-2_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 01 (run 1): 136.0s, 128 events
#   ✓ Song 02 (run 2): 124.9s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-03/eeg/sub-002_ses-03_task-MusicListening_run-3_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 03 (run 3): 142.8s, 128 events
#   ✓ Song 04 (run 4): 121.5s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-04/eeg/sub-002_ses-04_task-MusicListening_run-4_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-05/eeg/sub-002_ses-05_task-MusicListening_run-5_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 05 (run 5): 134.6s, 128 events
#   ✓ Song 06 (run 6): 110.1s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-06/eeg/sub-002_ses-06_task-MusicListening_run-6_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-07/eeg/sub-002_ses-07_task-MusicListening_run-7_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 107 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-08/eeg/sub-002_ses-08_task-MusicListening_run-8_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 07 (run 7): 126.5s, 128 events
#   ✓ Song 08 (run 8): 131.8s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-09/eeg/sub-002_ses-09_task-MusicListening_run-9_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 09 (run 9): 136.5s, 128 events
#   ✓ Song 10 (run 10): 139.5s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-10/eeg/sub-002_ses-10_task-MusicListening_run-10_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-11/eeg/sub-002_ses-11_task-MusicListening_run-11_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 11 (run 11): 123.1s, 128 events
#   ✓ Song 12 (run 12): 127.8s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 109 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-002/ses-12/eeg/sub-002_ses-12_task-MusicListening_run-12_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# Loading subject 003 (musin-g):
#   ✓ Song 01 (run 1): 136.0s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-01/eeg/sub-003_ses-01_task-MusicListening_run-1_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-02/eeg/sub-003_ses-02_task-MusicListening_run-2_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-03/eeg/sub-003_ses-03_task-MusicListening_run-3_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 02 (run 2): 124.9s, 128 events
#   ✓ Song 03 (run 3): 142.8s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-04/eeg/sub-003_ses-04_task-MusicListening_run-4_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 04 (run 4): 121.5s, 128 events
#   ✓ Song 05 (run 5): 134.6s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-05/eeg/sub-003_ses-05_task-MusicListening_run-5_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-06/eeg/sub-003_ses-06_task-MusicListening_run-6_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 06 (run 6): 110.1s, 128 events
#   ✓ Song 07 (run 7): 126.5s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-07/eeg/sub-003_ses-07_task-MusicListening_run-7_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 107 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-08/eeg/sub-003_ses-08_task-MusicListening_run-8_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-09/eeg/sub-003_ses-09_task-MusicListening_run-9_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 08 (run 8): 131.8s, 128 events
#   ✓ Song 09 (run 9): 136.5s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-10/eeg/sub-003_ses-10_task-MusicListening_run-10_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 10 (run 10): 139.5s, 128 events
#   ✓ Song 11 (run 11): 123.1s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-11/eeg/sub-003_ses-11_task-MusicListening_run-11_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 109 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-003/ses-12/eeg/sub-003_ses-12_task-MusicListening_run-12_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 12 (run 12): 127.8s, 128 events
# Loading subject 004 (musin-g):
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-01/eeg/sub-004_ses-01_task-MusicListening_run-1_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 01 (run 1): 136.0s, 128 events
#   ✓ Song 02 (run 2): 124.9s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-02/eeg/sub-004_ses-02_task-MusicListening_run-2_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-03/eeg/sub-004_ses-03_task-MusicListening_run-3_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 03 (run 3): 142.8s, 128 events
#   ✓ Song 04 (run 4): 121.5s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-04/eeg/sub-004_ses-04_task-MusicListening_run-4_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-05/eeg/sub-004_ses-05_task-MusicListening_run-5_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-06/eeg/sub-004_ses-06_task-MusicListening_run-6_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 05 (run 5): 134.6s, 128 events
#   ✓ Song 06 (run 6): 110.1s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 110 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-07/eeg/sub-004_ses-07_task-MusicListening_run-7_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 107 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Other is not an MNE-Python coordinate frame for EEG data and so will be set to 'unknown'
#   raw = read_raw_bids(bids_path, verbose=False)
#   ✓ Song 07 (run 7): 126.5s, 128 events
#   ✓ Song 08 (run 8): 131.8s, 128 events
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: participants.tsv file not found for datasets/musin_g_data/sub-004/ses-08/eeg/sub-004_ses-08_task-MusicListening_run-8_eeg.set
#   raw = read_raw_bids(bids_path, verbose=False)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/bcmi.py:1527: RuntimeWarning: Omitted 106 annotation(s) that were outside data range.
#   raw = read_raw_bids(bids_path, verbose=False)
# ...
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 134579  =      0.000 ...   134.579 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.52 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 110080  =      0.000 ...   110.080 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.42 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 126513  =      0.000 ...   126.513 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.919 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 131795  =      0.000 ...   131.795 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.486 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 136512  =      0.000 ...   136.512 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.204 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 139497  =      0.000 ...   139.497 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.487 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 123146  =      0.000 ...   123.146 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.502 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 127830  =      0.000 ...   127.830 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.853 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 136046  =      0.000 ...   136.046 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.169 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 124913  =      0.000 ...   124.913 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.953 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 142795  =      0.000 ...   142.795 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.086 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 121463  =      0.000 ...   121.463 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.204 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 134596  =      0.000 ...   134.596 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.536 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 110063  =      0.000 ...   110.063 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.403 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 126513  =      0.000 ...   126.513 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.936 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 131797  =      0.000 ...   131.797 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.486 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 136512  =      0.000 ...   136.512 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.202 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 139495  =      0.000 ...   139.495 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.487 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 123146  =      0.000 ...   123.146 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.504 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 127829  =      0.000 ...   127.829 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.853 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 136046  =      0.000 ...   136.046 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.17 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 124913  =      0.000 ...   124.913 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.953 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 142779  =      0.000 ...   142.779 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.086 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 121463  =      0.000 ...   121.463 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.22 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 134579  =      0.000 ...   134.579 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.536 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 110063  =      0.000 ...   110.063 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.42 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 126512  =      0.000 ...   126.512 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.936 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 131796  =      0.000 ...   131.796 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.487 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 136514  =      0.000 ...   136.514 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.203 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 139495  =      0.000 ...   139.495 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.485 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 123146  =      0.000 ...   123.146 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.504 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 127829  =      0.000 ...   127.829 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.853 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 136032  =      0.000 ...   136.032 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.17 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 124915  =      0.000 ...   124.915 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.967 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 142783  =      0.000 ...   142.783 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.084 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 121467  =      0.000 ...   121.467 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.216 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 134581  =      0.000 ...   134.581 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.532 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 110065  =      0.000 ...   110.065 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.418 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 126516  =      0.000 ...   126.516 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.934 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 131799  =      0.000 ...   131.799 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.483 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 136515  =      0.000 ...   136.515 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.2 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 139481  =      0.000 ...   139.481 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.484 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 123149  =      0.000 ...   123.149 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.518 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# Reading 0 ... 127815  =      0.000 ...   127.815 secs...
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.85 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)
# /home/zmrocze/studia/uwr/eeg-magisterka/src/eeg_music/data.py:493: RuntimeWarning: EDF format requires equal-length data blocks, so 0.184 seconds of edge values were appended to all channels when writing the final block.
#   mne.export.export_raw(filepath, self.raw_eeg, fmt="edf", overwrite=True)

# %%
ds = EEGMusicDataset.load_ondisk(Path("./datasets/musing_g_export_3"))
len(ds)
# Out:
# 240

# %%
ds[0]
# Out:
# TrialData(dataset='musin-g', subject='001', session='01', run='1', trial_id='song_01', music_filename=MusicFilename(filename='song_01.wav'), eeg_data=OnDiskEeg(filepath=PosixPath('datasets/musing_g_export_3/eeg/musin-g/001/01/1/song_01/eeg.edf')), music_data=MusingMusicIdData(music_id=MusingMusicId(song_id=1)))
