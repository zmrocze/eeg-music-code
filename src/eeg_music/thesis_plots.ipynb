# %%
from eeg_music.plotting import plot_band_power_with_onsets
from eeg_music.data import EEGMusicDataset, MappedDataset, trial_to_arrayeeg
from pathlib import Path

train_ds = EEGMusicDataset.load_ondisk(Path("./datasets/bcmi_preprocessed/bcmi_training_export/"))
# test_ds =EEGMusicDataset.load_ondisk(Path("./datasets/bcmi_preprocessed/bcmi_test_ica_40ch/"))

len(train_ds)
# Out:
# 3456

# %%
ds = MappedDataset(train_ds , trial_to_arrayeeg)

# %%
plot_band_power_with_onsets(ds[0])
